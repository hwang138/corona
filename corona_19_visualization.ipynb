# %% [markdown]
# ### Visualization of the latest Covid-19 data
#
#
# This report uses data from the<br>
# European Centre for Disease Prevention and Control [(ecdc)](
# https://www.ecdc.europa.eu/en/geographical-distribution-2019-ncov-cases
# )
#
# To donwload the csv file: [link](
# https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide
# )
#
# Currently only reporting on these countries:
# - United_States_of_America
# - Taiwan
# - Italy
# - Spain
# - Germany
# - China

# %%
from corona.corona import Corona

# %load_ext nb_black
# %load_ext autoreload
# %autoreload 2

# %%
corona = Corona()
# Out:
# ############
# Data Ingest
# ############
# UTC date and time: 2020-04-20 10:39:48
# Dataset pulled from: https://opendata.ecdc.europa.eu/covid19/casedistribution/csv
#
# ###############
# Data Processing
# ###############
# compute cumulative values ... working ... done.

# %%
corona.print_latest_case_numbers(day_range=3)
# Out:
# Case and death numbers for the last 3 days.
#          date countries_and_territories  cases  cumulative_cases  deaths  \
# 0  2020-04-20                    Global  74139           2355853    5145
# 1  2020-04-19                    Global  84121           2281714    6421
# 2  2020-04-18                    Global  83324           2197593    8263
# 3  2020-04-20  United_States_of_America  24601            759687    1772
# 4  2020-04-19  United_States_of_America  32922            735086    1856
# 5  2020-04-18  United_States_of_America  30833            702164    3770
# 6  2020-04-20                     Spain   4218            195944     410
# 7  2020-04-19                     Spain   3658            191726     565
# 8  2020-04-18                     Spain   5252            188068     348
# 9  2020-04-20                     Italy   3047            178972     433
# 10 2020-04-19                     Italy   3491            175925     480
# 11 2020-04-18                     Italy   3493            172434     575
# 12 2020-04-20                   Germany   1775            141672     110
# 13 2020-04-19                   Germany   2458            139897     184
# 14 2020-04-18                   Germany   3609            137439     242
# 15 2020-04-20                     China     14             83817       0
# 16 2020-04-19                     China     18             83803       0
# 17 2020-04-18                     China     31             83785       0
# 18 2020-04-20                    Taiwan     22               420       0
# 19 2020-04-19                    Taiwan      3               398       0
# 20 2020-04-18                    Taiwan      0               395       0
#
#     cumulative_deaths
# 0              164656
# 1              159511
# 2              153090
# 3               40682
# 4               38910
# 5               37054
# 6               20453
# 7               20043
# 8               19478
# 9               23660
# 10              23227
# 11              22747
# 12               4404
# 13               4294
# 14               4110
# 15               4636
# 16               4636
# 17               4636
# 18                  6
# 19                  6
# 20                  6

# %%
corona.plot_data()
